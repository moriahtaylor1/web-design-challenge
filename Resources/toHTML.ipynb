# %%
#pandas package
import pandas as pd

# %%
#load data
data = pd.read_csv("data.csv", index_col=0)

# %%
data.head()
# Out:
#          id Diagnosis   Area  Compactness  Concavity  Radius  Symmetry  \
# 1   8510426    Benign  566.3      0.08129    0.06664  13.540    0.1885
# 2   8510653    Benign  520.0      0.12700    0.04568  13.080    0.1967
# 3   8510824    Benign  273.9      0.06492    0.02956   9.504    0.1815
# 4    854941    Benign  523.8      0.03766    0.02562  13.030    0.1467
# 5  85713702    Benign  201.9      0.05943    0.01588   8.196    0.1769
#
#    Texture
# 1    14.36
# 2    15.71
# 3    12.44
# 4    18.42
# 5    16.84

# %%
print(data.to_html(bold_rows=False, col_space=150, justify='center', index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th style="min-width: 150px;">id</th>
#       <th style="min-width: 150px;">Diagnosis</th>
#       <th style="min-width: 150px;">Area</th>
#       <th style="min-width: 150px;">Compactness</th>
#       <th style="min-width: 150px;">Concavity</th>
#       <th style="min-width: 150px;">Radius</th>
#       <th style="min-width: 150px;">Symmetry</th>
#       <th style="min-width: 150px;">Texture</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>8510426</td>
#       <td>Benign</td>
#       <td>566.3</td>
#       <td>0.08129</td>
#       <td>0.066640</td>
#       <td>13.540</td>
#       <td>0.1885</td>
#       <td>14.36</td>
#     </tr>
#     <tr>
#       <td>8510653</td>
#       <td>Benign</td>
#       <td>520.0</td>
#       <td>0.12700</td>
#       <td>0.045680</td>
#       <td>13.080</td>
#       <td>0.1967</td>
#       <td>15.71</td>
#     </tr>
#     <tr>
# ...
